# %%
# !pip install pandas
import pandas as pd

# %%
df = pd.read_csv("../v0/AARTIIND__EQ__NSE__NSE__MINUTE.csv")

# %%
print(df.head().to_markdown())
# Out:
# |    | timestamp                 |   open |   high |   low |   close |   volume |
# |---:|:--------------------------|-------:|-------:|------:|--------:|---------:|
# |  0 | 2017-01-02 09:15:00+05:30 |  340   |  340   | 340   |   340   |       11 |
# |  1 | 2017-01-02 09:16:00+05:30 |  340   |  340   | 340   |   340   |        0 |
# |  2 | 2017-01-02 09:17:00+05:30 |  340   |  340   | 340   |   340   |        0 |
# |  3 | 2017-01-02 09:18:00+05:30 |  340   |  343.7 | 340   |   343.7 |        1 |
# |  4 | 2017-01-02 09:19:00+05:30 |  343.7 |  343.7 | 343.7 |   343.7 |        1 |

# %%
df = pd.read_csv("../processed_data/processed_v0/processed_AARTIIND__EQ__NSE__NSE__MINUTE.csv")

# %%
print(df.head().to_markdown())
# Out:
# |    | timestamp                 |   open |   high |   low |   close |   volume |   rolling_avg_10 |   volume_sum_10 |   future_close |   target |
# |---:|:--------------------------|-------:|-------:|------:|--------:|---------:|-----------------:|----------------:|---------------:|---------:|
# |  0 | 2017-01-02 09:15:00+05:30 |  340   |  340   | 340   |   340   |       11 |          340     |              11 |         341    |        1 |
# |  1 | 2017-01-02 09:16:00+05:30 |  340   |  340   | 340   |   340   |        0 |          340     |              11 |         339    |        0 |
# |  2 | 2017-01-02 09:17:00+05:30 |  340   |  340   | 340   |   340   |        0 |          340     |              11 |         338    |        0 |
# |  3 | 2017-01-02 09:18:00+05:30 |  340   |  343.7 | 340   |   343.7 |        1 |          340.925 |              12 |         338.95 |        0 |
# ...
